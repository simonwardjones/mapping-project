# %% [markdown]
# # Creating a Map displaying all the flights I have ever taken and more....

# %% [markdown]
# ## This project started on 24/09/16

# %%
import pandas as pd
import os

cwd = os.getcwd()
print (cwd)
# Out:
# C:\users\vz28\Mapping project\python mapping

# %% [markdown]
# ## Loading the data into a pandas data frame

# %%
# define the expected CSV columns
csv_cols = ('flight', 'dep_coutry', 'dep_airport','dep_airport_code','dep_lat','dep_lon',
            'arr_country','arr_airport','arr_airport_code','arr_lat','arr_lon',
            'date', 'notes','trip_name')

#define the input
in_filename = cwd + '\Data\SW-J flight travel.csv'
print (in_filename)

# Load in the file 
routes= pd.read_csv(in_filename,names= csv_cols, skiprows=1)
# Out:
# C:\users\vz28\Mapping project\python mapping\Data\SW-J flight travel.csv

# %% [markdown]
# ## Looking at the data

# %%
routes
# Out:
#     flight     dep_coutry        dep_airport dep_airport_code    dep_lat  \
# 0        1             UK           Heathrow              LHR  51.477500
# 1        2  United States      San Francisco              SFO  37.618972
# 2        3             UK           Heathrow              LHR  51.477500
# 3        4  United States             Boston              BOS  42.364347
# 4        5             UK           Heathrow              LHR  51.477500
# 5        6  United States        Los Angeles              LAX  33.942536
# 6        7             UK           Heathrow              LHR  51.477500
# 7        8  United States            Chicago              ORD  41.978603
# 8        9             UK              Luton              LTN  51.874722
# 9       10    Switzerland             Geneva              GVA  46.238064
# 10      11             UK              Luton              LTN  51.874722
# 11      12         Cyprus             Pathos              AOK  35.421408
# 12      13             UK           Heathrow              LHR  51.477500
# 13      14         India              Bombay              BOM  19.088686
# 14      15       Thailand            Bangkok              BKK  13.681108
# 15      16       Thailand             PhUKet              HKT   8.113200
# 16      17       Thailand            Bangkok              BKK  13.681108
# 17      18             UK              Luton              LTN  51.874722
# 18      19         Greece          Zakynthos              ZTH  37.750853
# 19      20             UK              Luton              LTN  51.874722
# 20      21       Portugal             Lisbon              LIS  38.781311
# 21      22             UK           Stansted              STN  51.885000
# 22      23          Italy             Verona              NaN  45.472017
# 23      24             UK           Stansted              STN  51.885000
# 24      25          Italy             Verona              NaN  45.472017
# 25      26             UK              Luton              LTN  51.874722
# 26      27       Portugal             Lisbon              LIS  38.781311
# 27      28             UK         Birmingham              BHX  52.453856
# 28      29         France             Nantes              NTE  47.153189
# 29      30             UK           Stansted              STN  51.885000
# ..     ...            ...                ...              ...        ...
# 47      48             UK              Luton              LTN  51.874722
# 48      49        Germany  Berlin Schonefeld              SXF  52.380001
# 49      50             UK            Gatwick              LGW  51.148056
# 50      51         France           Toulouse              TLS  43.629075
# 51      52             UK              Luton              LTN  51.874722
# 52      53        Croatia             Zagreb              ZAG  45.742931
# 53      54         Serbia            Beograd              BEG  44.818444
# 54      55             UK           Heathrow              LHR  51.477500
# 55      56         Turkey           Istanbul              IST  40.976922
# 56      57             UK           Heathrow              LHR  51.477500
# 57      58         India           Bangalore              BLR  12.949986
# 58      59         India               Delhi              DEL  28.566500
# 59      60       Germany   Berlin Schonefeld              SXF  52.380001
# 60      61             UK              Luton              LTN  51.874722
# 61      62             UK            Gatwick              LGW  51.148056
# 62      63        Germany            Hamburg              HAM  53.630389
# 60   -0.368333        Germany  Berlin Schonefeld              SXF  52.380001
# 61   -0.190278        Germany            Hamburg              HAM  53.630389
# 62    9.988228             UK            Gatwick              LGW  51.148056
# 63    0.235000         Greece             Athens              ATH  37.936358
# 64   23.944467             UK           Stansted              STN  51.885000
# 65   -0.368333        Poland              Gdansk              GDN  54.377569
# 66   18.466222             UK              Luton              LTN  51.874722
# 67   -0.461389       Thailand            Bangkok              BKK  13.681108
# 68  100.747283       Cambodia          Siem-reap              REP  13.410666
# 69  103.812840      Thailand             Bangkok              BKK  13.681108
# 70  100.606750       Thailand             PhUKet              HKT   8.113200
# 71   98.316872      Thailand             Bangkok              DMK  13.912583
# 72  100.747283             UK           Heathrow              LHR  51.477500
# 73   -0.461389            USA            Detroit              DTW  42.212444
# 74  -83.353389            USA             Denver              DEN  39.861656
# 75 -104.673178            USA     Salt Lake City              SLC  40.788389
# 76 -111.977772             UK           Heathrow              LHR  51.477500
#
#        arr_lon        date                       notes  \
# 0  -118.408075  01/08/2000              estimated date
# 1    -0.461389  15/08/2000              estimated date
# 2   -71.005181  01/08/2002              estimated date
# 3    -0.461389  12/08/2002              estimated date
# 4  -118.408075  01/08/2004              estimated date
# 5    -0.461389  15/08/2004              estimated date
# 6   -87.904842  22/10/2004              estimated date
# 7    -0.461389  29/10/2004              estimated date
# 8     6.108950  01/04/2007              estimated date
# 9    -0.368333  08/04/2007              estimated date
# 10   27.146008  01/08/2008              estimated date
# 11   -0.368333  15/08/2008              estimated date
# 12   72.867919  16/08/2008                  Via Bombay
# 13  100.747283  16/08/2008                  Via Bombay
# 14   98.316872  23/08/2008                         NaN
# 15  100.747283  27/08/2008                         NaN
# 16   -0.461389  29/08/2008                         NaN
# 17   20.884250  03/07/2010  estimated date and aiports
# 18   -0.368333  10/07/2010  estimated date and aiports
# 19   -9.135919  09/04/2011              estimated date
# 20   -0.368333  16/04/2011              estimated date
# 21   10.927919  17/04/2011  estimated date and aiports
# 22    0.235000  23/04/2011  estimated date and aiports
# 23   10.927919  01/04/2012  estimated date and aiports
# 24    0.235000  07/04/2012  estimated date and aiports
# 25   -9.135919  02/07/2012              estimated date
# 26   -0.368333  08/07/2012              estimated date
# 27   -1.610725  10/07/2012  estimated date and aiports
# 28   -1.748028  15/07/2012  estimated date and aiports
# 29   -5.893106  23/09/2012                         NaN
# ..         ...         ...                         ...
# 47   13.522500  22/01/2015                         NaN
# 48    0.235000  25/01/2015                         NaN
# 49    2.078464  09/05/2015                         NaN
# 50   -0.368333  16/05/2015                         NaN
# 51   14.457611  12/09/2015                         NaN
# 52   20.309139  19/09/2015                Via belgrade
# 53   -0.461389  19/09/2015                Via belgrade
# 54   28.814606  19/11/2015                         NaN
# 55   -0.190278  22/11/2015                         NaN
# 56   77.668206  09/01/2016                         NaN
# 57   77.103088  30/01/2016                   via Dehli
# 58   -0.461389  30/01/2016                   via Dehli
# 59   -0.368333  04/03/2016                         NaN
# 60   13.522500  06/03/2016                         NaN
# 61    9.988228  17/04/2016                         NaN
# 62   -0.190278  20/04/2016                         NaN
# 63   23.944467  18/06/2016                         NaN
# 64    0.235000  25/06/2016                         NaN
# 65   18.466222  28/06/2016                         NaN
# 66   -0.368333  03/07/2016                         NaN
# 67  100.747283  21/08/2016                         NaN
# 68  103.812840  15/09/2016                         NaN
# 69  100.747283  18/09/2016                         NaN
# 70   98.316872  18/10/2016                         NaN
# 71  100.606750  22/10/2016                         NaN
# 72   -0.461389  02/12/2016                         NaN
# 73  -83.353389  10/12/2016                 via detroit
# 74 -104.673178  10/12/2016                 via detroit
# 75 -111.977772  20/12/2016          via salt lake city
# 76   -0.461389  20/12/2016          via salt lake city
#
#                         trip_name
# 0          Family United States 1
# 1          Family United States 1
# 2          Family United States 2
# 3          Family United States 2
# 4          Family United States 3
# 5          Family United States 3
# 6   Aunty Jill United States trip
# 7   Aunty Jill United States trip
# 8                         Avoriaz
# 9                         Avoriaz
# 10                  Family Cyprus
# 11                  Family Cyprus
# 12              Family Thailand 1
# 13              Family Thailand 1
# 14              Family Thailand 1
# 15              Family Thailand 1
# 16              Family Thailand 1
# 17                          Zante
# 18                          Zante
# 19               Portugal Surfing
# 20               Portugal Surfing
# 21                 Mantrowva 2011
# 22                 Mantrowva 2011
# 23                 Mantrowva 2012
# 24                 Mantrowva 2012
# 25  Portugal with Rich and Claire
# 26  Portugal with Rich and Claire
# 27                        Beganne
# 28                        Beganne
# 29  Mum, Dad, me seville 3rd year
# ..                            ...
# 47                     Silke Trip
# 48                     Silke Trip
# 49          Stan, Zo and Si Cycle
# 50          Stan, Zo and Si Cycle
# 51                       Slovatia
# 52                       Slovatia
# 53                       Slovatia
# 54                 Lattice Turkey
# 55                 Lattice Turkey
# 56                India with Work
# 57                India with Work
# 58                India with Work
# 59                 Richard's Stag
# 60                 Richard's Stag
# 61            Teradata Conference
# 62            Teradata Conference
# 63                   The Big Sail
# 64                   The Big Sail
# 65                 Lattice Open'r
# 66                 Lattice Open'r
# 67             Thailand with Work
# 68               Family Camobia 1
# 69               Family Camobia 1
# 70              Issie Island trip
# 71              Issie Island trip
# 72             Home from Thailand
# 73            Alex/Al Skiing trip
# 74            Alex/Al Skiing trip
# 75            Alex/Al Skiing trip
# 76            Alex/Al Skiing trip
#
# [77 rows x 14 columns]

# %%
routes.index
# Out:
# RangeIndex(start=0, stop=77, step=1)

# %%
routes['dep_lat'][0]   ## data selection similar to an Sframe in graphlab
# Out:
# 51.477499999999999

# %% [markdown]
# ### Try to ignore anything about colour - old code

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import numpy as np
import pandas as pd
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize, LinearSegmentedColormap, PowerNorm
import os

def plot_map(in_filename, color_mode='screen',
             out_filename='flights_map_mpl.png', absolute=False):
    """Plots the given CSV data files use matplotlib basemap and saves it to
    a PNG file.
    Args:
        in_filename: Filename of the CSV containing the data points.
        out_filename: Output image filename
        color_mode: Use 'screen' if you intend to use the visualisation for
                    on screen display. Use 'print' to save the visualisation
                    with printer-friendly colors.
        absolute: set to True if you want coloring to depend on your dataset
                  parameter value (ie for comparison).
                  When set to false, each coordinate pair gets a different
                  color.
    """

    if color_mode == 'screen':
        bg_color = (0.0, 0.0, 0, 1.0)
        coast_color = (10/255.0, 255/255.0, 71/255.0, 0.7)
        color_list = [(0.0, 0.0, 0.0, 0.0),
                      (204/255.0, 0, 153/255.0, 0.6),
                      (255/255.0, 204/255.0, 230/255.0, 1.0)]
        """        bg_color = (0.0, 0.0, 0, 1.0)
        coast_color = (204/255.0, 0, 153/255.0, 0.7)
        color_list = [(0.0, 0.0, 0.0, 0.0),
                      (204/255.0, 0, 153/255.0, 0.6),
                      (255/255.0, 204/255.0, 230/255.0, 1.0)]"""
    else:
        bg_color = (1.0, 1.0, 1.0, 1.0)
        coast_color = (10.0/255.0, 10.0/255.0, 10/255.0, 0.8)
        color_list = [(1.0, 1.0, 1.0, 0.0),
                      (255/255.0, 204/255.0, 230/255.0, 1.0),
                      (204/255.0, 0, 153/255.0, 0.6)
                      ]

        # define the expected CSV columns
    csv_cols = ('flight', 'dep_coutry', 'dep_airport','dep_airport_code','dep_lat','dep_lon',
                'arr_country','arr_airport','arr_airport_code','arr_lat','arr_lon',
                'date', 'notes','trip_name')

  
    # Load in the file 
    routes = pd.read_csv(in_filename,names= csv_cols, skiprows=1)
    
    # create the map and draw country boundaries
    plt.figure(figsize=(27, 20))
    m = Basemap(projection='mill', lon_0=0, resolution= 'l')
    # other projections are possible e.g. m = Basemap(projection='ortho',lat_0=10,lon_0=0,resolution='l')
    m.drawcoastlines(color=coast_color, linewidth=1.0)
    m.fillcontinents(color=bg_color, lake_color=bg_color)
    m.drawmapboundary(fill_color=bg_color)

    # plot each route with its color depending on the number of flights
    for i, route in enumerate(routes.sort_values(by='flight',
                              ascending=True).iterrows()):
        route = route[1]
        color = (204/255.0, 0, 193/255.0, .9)
       

        line, = m.drawgreatcircle(route['dep_lon'], route['dep_lat'],
                                  route['arr_lon'], route['arr_lat'],
                                  linewidth=2, color=color)
        
        # if the path wraps the image, basemap plots a nasty line connecting
        # the points at the opposite border of the map.
        # we thus detect path that are bigger than 30km and split them
        # by adding a NaN
        path = line.get_path()
        cut_point, = np.where(np.abs(np.diff(path.vertices[:, 0])) > 30000e3)
        if len(cut_point) > 0:
            cut_point = cut_point[0]
            vertices = np.concatenate([path.vertices[:cut_point, :],
                                      [[np.nan, np.nan]],
                                      path.vertices[cut_point+1:, :]])
            path.codes = None  # treat vertices as a serie of line segments
            path.vertices = vertices

    # save the map
    plt.savefig(out_filename, format='png', bbox_inches='tight')

if __name__ == '__main__':
    # use 'screen' color mode for on-screen display. Use 'print' if you intend
    # to print the map
    #define the input
    cwd = os.getcwd()
    in_filename = cwd + '\Data\SW-J flight travel.csv'
    print (in_filename)

    plot_map(in_filename,'screen', absolute=False)
# Out:
# C:\users\vz28\Mapping project\python mapping\Data\SW-J flight travel.csv
# D:\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py:3274: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# D:\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py:3283: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# D:\Anaconda3\lib\site-packages\ipykernel\__main__.py:78: RuntimeWarning: invalid value encountered in greater

# %% [markdown]
# ## We can view it here using plt.show()

# %%
plt.title('Simon\'s Travel')
plt.show()

# %% [markdown]
# # And some random list analysys

# %%
list = ['dffd',1,21,1]

# %%
list2 = [list,'w']

# %%
print list2
# Out:
# [['dffd', 1, 21, 1], 'w']

# %% [markdown]
# # Coulour checker

# %%
coast_color = (4/255.0, 0,10/255.0, 0.7)
f = plt.figure(facecolor= coast_color)
plt.show()
